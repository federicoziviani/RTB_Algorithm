# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
pCTR_train = pd.read_pickle('pCTR_validation')
rtb_validation = pd.read_csv('validation.csv')

# %% [markdown]
# # Linear Bidding using Random Forrest for CTR predicion

# %% [markdown]
# Set Base

# %%
# Make a table with the bidprice with premium only for impressions with  50%+ of click probability, otherwise bid 0.
# inear_bid = avgPayprice/1000 * (2*stDev)
df = pd.read_pickle('linear_bid')
df1 = df.drop(columns = ['bidprice', 'linear_bid'] )

df1['pCTR'].max()
#premium based on taking all impressions with click prob > 0.65
df1['premium'] = 3*df1['pCTR']
df1['bidPrice'] = 19
df1['impression'] = 0

#base_bid = validation_payprice.mean()/1000 + (2*std )
df1 ['base_bid'] = df ['linear_bid']
#update bidPrice column with premium
df1.loc[df.pCTR>=0.5, 'bidPrice'] = df1['premium'] * df1['base_bid']

#update impression column 
df1['impression'] = np.where ((df1['bidPrice'] >= df1['payprice']), 1, 0)
#df1['impression'].count()

#check the clicks

culo = df1['click'] == 1 
culo.groupby(df1['click']).count()
df1.head()
#df1.loc[df.impression == 1 & df.click == 1, 'bidPrice'] = df1['premium'] + df1['linear_bid']
#df1['pCTR'].max()
#df1['bidPrice'].mean()
# Out:
#        pCTR  click                                     bidid  payprice  \
# 0  0.386555      0  bbcb813b6166538503d8b33a5602d7d72f6019dc        23
# 1  0.386555      0  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d        75
# 2  0.386555      0  f6ece71dae81d6b16bfb24ad6dd5611472d4c673        65
# 3  0.386555      0  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb         6
# 4  0.386555      0  0899bf144249458ea9c89188473694bf44c7ca15         5
#
#     premium  bidPrice  impression   base_bid
# 0  1.159664      19.0           0  81.996435
# 1  1.159664      19.0           0  81.996435
# 2  1.159664      19.0           0  81.996435
# 3  1.159664      19.0           1  81.996435
# 4  1.159664      19.0           1  81.996435

# %%
#run the algorithm to sepend the budget

budget = 6250
impressions = 0
bids = 0
clicks = 0
for i in range(0, len(df1)):
    if budget > 0 and budget > (df1['payprice'].values[i]/1000):
        impressions += 1
        if (df1['bidPrice'].values[i]) > (df1['payprice'].values[i]):
            budget = budget - (df1['payprice'].values[i]/1000)
            bids += 1
            clicks += df1['click'].values[i] 
    else:
        print("Budget is spent!")
        break
consumedBudget = 6250 - budget
ctr = (clicks/bids)*100   
cpm = ((consumedBudget)/bids)*1000
cpc = (consumedBudget)/clicks 
#Output for the alrogithm
print("Output")
print("Number of Bids:",bids)
print("Number of Impressions:",impressions)
print("Number of Clicks:", clicks)
print("CTR is:",ctr, "%")
print("CPM is:",cpm)
print("CPC is:",cpc)
print(consumedBudget)
# Out:
# Budget is spent!
# Output
# Number of Bids: 95273
# Number of Impressions: 285501
# Number of Clicks: 103
# CTR is: 0.10811037754662915 %
# CPM is: 65.59989713770462
# CPC is: 60.67863106796632
# 6249.8990000005315

# %% [markdown]
# # Liear Bidding using Decision Tree for CTR prediction

# %%
decision_tree_val = pd.read_pickle('decision_tree_val')
decision_tree_val.head()
# Out:
#        pCTR  click
# 0  0.357459      0
# 1  0.330309      0
# 2  0.357459      0
# 3  0.357459      0
# 4  0.330309      0

# %%
# Make a table with the bidprice with premium only for impressions with  65%+ of click probability, otherwise bid 0.
# inear_bid = avgPayprice/1000 * (2*stDev)
df = pd.read_pickle('linear_bid')
df3 = df.drop(columns = ['bidprice', 'linear_bid'] )

df3['pCTR'].max()
#premium based on taking all impressions with click prob > 0.65
df3['premium'] = 100*df3['pCTR']
df3['bidPrice'] = 21
df3['impression'] = 0
df3['pCTR'] = decision_tree_val ['pCTR']

#base_bid = validation_payprice.mean()/1000 + (2*std )
df3 ['base_bid'] = df ['linear_bid']

#update bidPrice column with premium
df3.loc[df.pCTR>=0.50, 'bidPrice'] = df3['premium'] + df3['base_bid']

#update impression column 
df3['impression'] = np.where ((df3['bidPrice'] >= df3['payprice']), 1, 0)


df3.head()
#df1.loc[df.impression == 1 & df.click == 1, 'bidPrice'] = df1['premium'] + df1['linear_bid']
#df1['pCTR'].max()
#df1['bidPrice'].mean()
# Out:
#        pCTR  click                                     bidid  payprice  \
# 0  0.357459      0  bbcb813b6166538503d8b33a5602d7d72f6019dc        23
# 1  0.330309      0  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d        75
# 2  0.357459      0  f6ece71dae81d6b16bfb24ad6dd5611472d4c673        65
# 3  0.357459      0  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb         6
# 4  0.330309      0  0899bf144249458ea9c89188473694bf44c7ca15         5
#
#      premium  bidPrice  impression   base_bid
# 0  38.655462      21.0           0  81.996435
# 1  38.655462      21.0           0  81.996435
# 2  38.655462      21.0           0  81.996435
# 3  38.655462      21.0           1  81.996435
# 4  38.655462      21.0           1  81.996435

# %%
#run the algorithm to sepend the budget

budget = 6250
impressions = 0
bids = 0
clicks = 0
for i in range(0, len(df3)):
    if budget > 0 and budget > (df3['payprice'].values[i]/1000):
        impressions += 1
        if (df3['bidPrice'].values[i]) > (df3['payprice'].values[i]):
            budget = budget - (df3['payprice'].values[i]/1000)
            bids += 1
            clicks += df3['click'].values[i] 
    else:
        print("Budget is spent!")
        break
consumedBudget = 6250 - budget
ctr = (clicks/bids)*100
cpm = ((consumedBudget)/bids)*1000
cpc = (consumedBudget)/clicks 
#Output for the alrogithm
print("Output")
print("Number of Bids:",bids)
print("Number of Impressions:",impressions)
print("Number of Clicks:", clicks)
print("CTR is:",ctr, "%")
print("CPM is:",cpm)
print("CPC is:",cpc)
print (budget)
print(consumedBudget)
# Out:
# Budget is spent!
# Output
# Number of Bids: 111497
# Number of Impressions: 300327
# Number of Clicks: 115
# CTR is: 0.10314178856830228 %
# CPM is: 56.05392073331555
# CPC is: 54.34646956523899
# 0.15599999751640048
# 6249.844000002484
