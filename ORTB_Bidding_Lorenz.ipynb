# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
pCTR_train = pd.read_pickle('pCTR_validation')
rtb_validation = pd.read_csv('validation.csv')

# %% [markdown]
# # ORTB using Ada Boost for CTR predicion

# %%
ada_boost_val = pd.read_pickle('ada_boost_val')
print(ada_boost_val.head())
bidPrices = []
lagr = 0.001
c = 70
# Out:
#        pCTR  click
# 0  0.491136      0
# 1  0.490874      0
# 2  0.491270      0
# 3  0.494251      0
# 4  0.482570      0

# %%
for i in range(0, len(rtb_validation)):
    price = np.sqrt((c/lagr)*ada_boost_val['pCTR'].values[i] + c**2) - c
    bidPrices.append(price)

# %%
rtb_validation.head()
# Out:
#    click  weekday  hour                                     bidid  \
# 0      0        4    20  bbcb813b6166538503d8b33a5602d7d72f6019dc
# 1      0        1    21  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d
# 2      0        4     8  f6ece71dae81d6b16bfb24ad6dd5611472d4c673
# 3      0        5    15  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb
# 4      0        1    18  0899bf144249458ea9c89188473694bf44c7ca15
#
#                                      userid       useragent             IP  \
# 0  663169f66491c98c69f1f94a5c48fa34aa9fe06f      windows_ie  211.144.203.*
# 1  a23f0cfab6592c137f796e68fa752fceba08bb1b  windows_chrome   58.247.250.*
# 2  5105a013ea54a9706146033e6a138d5234a3803e      windows_ie   117.12.111.*
# 3  577e9a768ce17e73c61ba7022db927f9ee761830  windows_chrome   61.187.224.*
# 4  e4bf79c562745d671b19f2edf7fda89c2e25987f  windows_chrome   117.41.145.*
#
#    region  city  adexchange                       ...                         \
# ...

# %%
#run the algorithm to sepend the budget

budget = 6250
impressions = 0
bids = 0
clicks = 0
for i in range(0, len(rtb_validation)):
    if budget > 0 and budget > (rtb_validation['payprice'].values[i]/1000):
        impressions += 1
        if (bidPrices[i]) > (rtb_validation['payprice'].values[i]):
            budget = budget - (rtb_validation['payprice'].values[i]/1000)
            bids += 1
            clicks += rtb_validation['click'].values[i] 
    else:
        print("Budget is spent!")
        break
consumedBudget = 6250 - budget
ctr = (clicks/bids)*100
cpm = ((consumedBudget)/bids)*1000
cpc = (consumedBudget)/clicks 
#Output for the alrogithm
print("Output")
print("Number of Bids:",bids)
print("Number of Impressions:",impressions)
print("Number of Clicks:", clicks)
print("CTR is:",ctr, "%")
print("CPM is:",cpm)
print("CPC is:",cpc)
print (budget)
print(consumedBudget)
# Out:
# Budget is spent!
# Output
# Number of Bids: 114367
# Number of Impressions: 139378
# Number of Clicks: 60
# CTR is: 0.05246268591464321 %
# CPM is: 54.647205924800396
# CPC is: 104.16395000002744
# 0.1629999983535546
# 6249.837000001647

# %% [markdown]
# # ORTB using Ada Boost for CTR predicion
